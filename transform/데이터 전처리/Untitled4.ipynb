# %%
import json
import pandas as pd

# %%
with open('./hospital_psy_hira.json', encoding='utf-8') as f:
    data = json.load(f)
data
# Out:
# [{'공공/민간': '민간',
#   '기관구분': '병원',
#   '기관명': '가톨릭대학교인천성모병원',
#   '주소': '인천광역시 부평구 동수로 56-  (부평동)',
#   'longitude': '126.7248987',
#   'latitude': '37.4848309',
#   '전화번호': '032-1544-9004',
#   '홈페이지': 'http://www.cmcism.or.kr/'},
#  {'공공/민간': '민간',
#   '기관구분': '병원',
#   '기관명': '강릉아산병원',
#   '주소': '강원도 강릉시 사천면 방동길 38 ()',
#   'longitude': '128.8578411',
#   'latitude': '37.8184325',
#   '전화번호': '033-610-3114',
#   '홈페이지': 'http://www.gnah.co.kr'},
#  {'공공/민간': '민간',
#   '기관구분': '병원',
#   '기관명': '강북삼성병원',
#   '주소': '서울특별시 종로구 새문안로 29 (평동)',
#   'longitude': '126.9677500',
#   'latitude': '37.5684083',
#   '전화번호': '02-2001-2001',
#   '홈페이지': 'http://www.kbsmc.co.kr'},
#  {'공공/민간': '민간',
#   '기관구분': '병원',
#   '기관명': '건국대학교병원',
#   '주소': '서울특별시 광진구 능동로 120-1 (화양동)',
#   'longitude': '127.0718276',
#   'latitude': '37.5403764',
#   '전화번호': '1588-1533',
#   '홈페이지': 'http://www.kuh.ac.kr'},
#  {'공공/민간': '민간',
#   '기관구분': '병원',
#   '기관명': '경북대학교병원',
# ...

# %%
list = []
for i in range(len(data)):
    list.append({
        'lat' : data[i]['latitude'],
        'lng' : data[i]['longitude'],
        'name' : data[i]['기관명']
    })
    
list
# Out:
# [{'lat': '37.4848309', 'lng': '126.7248987', 'name': '가톨릭대학교인천성모병원'},
#  {'lat': '37.8184325', 'lng': '128.8578411', 'name': '강릉아산병원'},
#  {'lat': '37.5684083', 'lng': '126.9677500', 'name': '강북삼성병원'},
#  {'lat': '37.5403764', 'lng': '127.0718276', 'name': '건국대학교병원'},
#  {'lat': '35.8667740', 'lng': '128.6041250', 'name': '경북대학교병원'},
#  {'lat': '35.1763252', 'lng': '128.0956717', 'name': '경상국립대학교병원'},
#  {'lat': '37.5941195', 'lng': '127.0518520', 'name': '경희대학교병원'},
#  {'lat': '35.8538856', 'lng': '128.4801315', 'name': '계명대학교동산병원'},
#  {'lat': '37.4920520', 'lng': '126.8848701', 'name': '고려대학교의과대학부속구로병원'},
#  {'lat': '37.3185144', 'lng': '126.8249033', 'name': '고려대학교의과대학부속안산병원'},
#  {'lat': '36.8415904', 'lng': '127.1725750', 'name': '단국대학교의과대학부속병원'},
#  {'lat': '35.8436078', 'lng': '128.5679969', 'name': '대구가톨릭대학교병원'},
#  {'lat': '35.1201900', 'lng': '129.0174250', 'name': '동아대학교병원'},
#  {'lat': '35.1008477', 'lng': '129.0188032', 'name': '부산대학교병원'},
# ...
