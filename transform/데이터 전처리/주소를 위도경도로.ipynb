# %%
import pandas as pd
import numpy as np
import pyproj

# %%
df = pd.read_csv('./adr-hospital.csv', encoding='cp949', usecols=['사업장명', '진료과목내용명', '좌표정보(x)', '좌표정보(y)', '도로명전체주소'])

df['좌표정보(x)'] = pd.to_numeric(df['좌표정보(x)'], errors='coerce')
df['좌표정보(y)'] = pd.to_numeric(df['좌표정보(y)'], errors='coerce')

df = df.dropna()

df = df[df['진료과목내용명'].str.contains('정신건강의학과')]
df.columns = ['address', 'corp_name', 'longitude', 'latitude', 'treatment_subject']
df.index = range(len(df))
df
# Out:
#                       address          corp_name    longitude     latitude  \
# 0           경상남도사천시사천읍구암두문로74             사천동희병원  299722.4204  177131.7783
# 1         경상남도양산시모래들1길91(주진동)               양산병원  394946.0000  213423.0000
# 2    경상남도창녕군고암면상대2길16더케이서드에이지            프라임요양병원  337000.3444  232019.5924
# 3    경상남도사천시향촌4길127(향촌동한마음병원)     (의)덕산의료재단한마음병원  300255.8831  160128.6480
# 4        경상남도사천시축동면서삼로1110-35  (의)순영의료재단경남도립정신병원  295277.7415  177495.1737
# ..                        ...                ...          ...          ...
# 704         전라남도고흥군도양읍소록해안길65            국립소록도병원  211401.4789  112823.6314
# 705  충청남도천안시서북구성정공원1길9-4(성정동)             충무사랑병원  212327.0362  369485.4505
# 706      충청남도당진시합덕읍합덕시장로174-1       정빈의료재단합덕아산병원  179810.8820  367418.2661
# 707        광주광역시북구유림로177(동림동)            동림허바킴병원  187560.9000  186653.5499
# 708     광주광역시남구독립로54번길26(백운동)              광주백병원  191242.8109  182123.7631
#
#                                      treatment_subject
# ...

# %%
ndf = pd.read_csv('./adr-public.csv', encoding='cp949', usecols=['기관명', '주소', '기관구분'])

ndf = ndf.dropna()

ndf.index = range(len(ndf))
ndf
ndf.columns = ['corp_name', 'div', 'address']
ndf
# Out:
#                 corp_name     div                    address
# 0               (복지)예사랑병원      병원   부산광역시서구옥천로130번길38(아미동2가)
# 1          (의)고담의료재단마더스병원      병원          울산광역시남구화합로107(달동)
# 2       (의)나사렛의료재단나사렛국제병원    종합병원       인천광역시연수구먼우금로98-(동춘동)
# 3         (의)아나의료재단강릉아나병원      병원            강원도강릉시용지로129129
# 4     (재)예수의꽃동네유지재단인곡자애병원      병원       충청북도음성군맹동면꽃동네길37-0()
# ...                   ...     ...                        ...
# 2781                  희망집  정신재활시설      경기도오산시경기동로8번길28라동102호
# 2782               히즈메디병원      병원         경기도김포시김포대로681(풍무동)
# 2783                 힐링타운  정신재활시설          대전광역시대덕구송촌남로55-12
# 2784                힐링하우스  정신재활시설  경기도안산시상록구석호공원로2길7401호(사동)
# 2785       李편한마음정신건강의학과의원      의원       대전광역시중구대흥로1053층(대흥동)
#
# [2786 rows x 3 columns]

# %%
result = pd.concat([df, ndf])
result.drop_duplicates(subset = 'corp_name', keep='first', inplace=True)
result.drop_duplicates(subset = 'address', keep='first', inplace=True)
result
# Out:
#                            address          corp_name    longitude  \
# 0                경상남도사천시사천읍구암두문로74             사천동희병원  299722.4204
# 1              경상남도양산시모래들1길91(주진동)               양산병원  394946.0000
# 2         경상남도창녕군고암면상대2길16더케이서드에이지            프라임요양병원  337000.3444
# 3         경상남도사천시향촌4길127(향촌동한마음병원)     (의)덕산의료재단한마음병원  300255.8831
# 4             경상남도사천시축동면서삼로1110-35  (의)순영의료재단경남도립정신병원  295277.7415
# ...                            ...                ...          ...
# 2778  광주광역시남구서문대로701번길2넥스타워5층(진월동)        희망정신건강의학과의원          NaN
# 2781         경기도오산시경기동로8번길28라동102호                희망집          NaN
# 2783             대전광역시대덕구송촌남로55-12               힐링타운          NaN
# 2784     경기도안산시상록구석호공원로2길7401호(사동)              힐링하우스          NaN
# 2785          대전광역시중구대흥로1053층(대흥동)     李편한마음정신건강의학과의원          NaN
#
#          latitude                                  treatment_subject     div
# 0     177131.7783        내과, 신경과, 정신건강의학과, 소아청소년과, 이비인후과, 피부과, 가정의학과     NaN
# ...

# %%
result01 = result[result['div'].isnull()]
result01.index = range(len(result01))
df_hospital = result01.drop(['div'],axis=1)
df_hospital
# Out:
#                                 address           corp_name    longitude  \
# 0                     경상남도사천시사천읍구암두문로74              사천동희병원  299722.4204
# 1                   경상남도양산시모래들1길91(주진동)                양산병원  394946.0000
# 2              경상남도창녕군고암면상대2길16더케이서드에이지             프라임요양병원  337000.3444
# 3              경상남도사천시향촌4길127(향촌동한마음병원)      (의)덕산의료재단한마음병원  300255.8831
# 4                  경상남도사천시축동면서삼로1110-35   (의)순영의료재단경남도립정신병원  295277.7415
# ..                                  ...                 ...          ...
# 679  경기도의정부시동일로712을지대학교의정부캠퍼스및부속병원(금오동)  학교법인을지학원의정부을지대학교병원  204500.5497
# 680         서울특별시도봉구방학로3길6SYO빌딩14층(방학동)              희성한방병원  203511.5333
# 681                   전라남도고흥군도양읍소록해안길65             국립소록도병원  211401.4789
# 682                  광주광역시북구유림로177(동림동)             동림허바킴병원  187560.9000
# 683               광주광역시남구독립로54번길26(백운동)               광주백병원  191242.8109
#
#         latitude                                  treatment_subject
# ...

# %%
result02 = result[result['longitude'].isnull()]
result02.index = range(len(result02))
df_mental = result02.drop(['longitude', 'latitude', 'treatment_subject','div'], axis = 1)
df_mental
# Out:
#                            address         corp_name
# 0              광주광역시북구태봉로32유동115-1       (재)천주의성요한병원
# 1                       관평로170번길22  (학)일송학원한림대학교성심병원
# 2                    부산광역시남구수영로165              BH병원
# 3            서울특별시광진구능동로3243층(중곡동)       Dr.고신경정신과의원
# 4         강원도강릉시경강로21096층(임당동문선빌딩)   Dr.신형직의비타민정신과의원
# ...                            ...               ...
# 1855  광주광역시남구서문대로701번길2넥스타워5층(진월동)       희망정신건강의학과의원
# 1856         경기도오산시경기동로8번길28라동102호               희망집
# 1857             대전광역시대덕구송촌남로55-12              힐링타운
# 1858     경기도안산시상록구석호공원로2길7401호(사동)             힐링하우스
# 1859          대전광역시중구대흥로1053층(대흥동)    李편한마음정신건강의학과의원
#
# [1860 rows x 2 columns]

# %%
def project_array(coord, p1_type, p2_type):
    """
    좌표계 변환 함수
    - coord: x, y 좌표 정보가 담긴 NumPy Array
    - p1_type: 입력 좌표계 정보 ex) epsg:5179
    - p2_type: 출력 좌표계 정보 ex) epsg:4326
    """
    p1 = pyproj.Proj(init=p1_type)
    p2 = pyproj.Proj(init=p2_type)
    fx, fy = pyproj.transform(p1, p2, coord[:, 0], coord[:, 1])
    return np.dstack([fx, fy])[0]

# %%
df_array = df_hospital.drop(['corp_name', 'treatment_subject','address'], axis=1)
df_array
# Out:
#        longitude     latitude
# 0    299722.4204  177131.7783
# 1    394946.0000  213423.0000
# 2    337000.3444  232019.5924
# 3    300255.8831  160128.6480
# 4    295277.7415  177495.1737
# ..           ...          ...
# 679  204500.5497  472325.1037
# 680  203511.5333  462249.7551
# 681  211401.4789  112823.6314
# 682  187560.9000  186653.5499
# 683  191242.8109  182123.7631
#
# [684 rows x 2 columns]

# %%
coord = np.array(df_array)

coord
# Out:
# array([[299722.4204, 177131.7783],
#        [394946.    , 213423.    ],
#        [337000.3444, 232019.5924],
#        ...,
#        [211401.4789, 112823.6314],
#        [187560.9   , 186653.5499],
#        [191242.8109, 182123.7631]])

# %%
p1_type = "epsg:2097"
p2_type = "epsg:4326"

result = project_array(coord, p1_type, p2_type)
result
# Out:
# C:\Users\by_wh\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\by_wh\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
df_hospital['longitude'] = result[:, 0]
df_hospital['latitude'] = result[:, 1]

df_hospital
# Out:
#                                 address           corp_name   longitude  \
# 0                     경상남도사천시사천읍구암두문로74              사천동희병원  128.091458
# 1                   경상남도양산시모래들1길91(주진동)                양산병원  129.143769
# 2              경상남도창녕군고암면상대2길16더케이서드에이지             프라임요양병원  128.509310
# 3              경상남도사천시향촌4길127(향촌동한마음병원)      (의)덕산의료재단한마음병원  128.095260
# 4                  경상남도사천시축동면서삼로1110-35   (의)순영의료재단경남도립정신병원  128.042768
# ..                                  ...                 ...         ...
# 679  경기도의정부시동일로712을지대학교의정부캠퍼스및부속병원(금오동)  학교법인을지학원의정부을지대학교병원  127.048965
# 680         서울특별시도봉구방학로3길6SYO빌딩14층(방학동)              희성한방병원  127.037695
# 681                   전라남도고흥군도양읍소록해안길65             국립소록도병원  127.122088
# 682                  광주광역시북구유림로177(동림동)             동림허바킴병원  126.861360
# 683               광주광역시남구독립로54번길26(백운동)               광주백병원  126.901829
#
#       latitude                                  treatment_subject
# ...

# %%
df_mental.to_excel('./hospital_mental_final.xlsx')
df_hospital.to_excel('./public_mental_final.xlsx')

# %% [markdown]
# # 도로명 주소 -> 위/경도

# %%
# !pip install geopy

# %%
# !pip install openpyxl

# %%
# !pip install geocoder

# %%
# !pip install googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38552 sha256=0f24aa04a01a7953fb2cf063fabd7ed3d9787f2742a6330bafb293b6fec17e52
#   Stored in directory: c:\users\by_wh\appdata\local\pip\cache\wheels\b6\23\aa\a130b53682531f8382dd06f2000001225bea7b56a99c516f87
# Successfully built googlemaps
# ...

# %%
import googlemaps
import pandas as pd

my_key = "AIzaSyA98GaV2pDkyU4DYx0IcCRNxecBtD8cXuQ"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.
fuxx = pd.read_excel('./please.xlsx', usecols=['address'])

places = fuxx ['address']

i=0
for place in places:   
    i = i + 1
    try:
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng}, index=places)

df.to_excel('./rest.xlsx')



'''
# output
1번 인덱스에서 강남의 위치를 찾고있습니다
2번 인덱스에서 황상동의 위치를 찾고있습니다
3번 인덱스에서 해운대해수욕장의 위치를 찾고있습니다
                위도          경도
강남       37.517236  127.047325
황상동      36.114955  128.440733
해운대해수욕장  35.158698  129.160384

'''
# Out:
# 134번 인덱스 위치를 찾는데 실패했습니다.
# '\n# output\n1번 인덱스에서 강남의 위치를 찾고있습니다\n2번 인덱스에서 황상동의 위치를 찾고있습니다\n3번 인덱스에서 해운대해수욕장의 위치를 찾고있습니다\n                위도          경도\n강남       37.517236  127.047325\n황상동      36.114955  128.440733\n해운대해수욕장  35.158698  129.160384\n\n'

# %%
import googlemaps
import pandas as pd

my_key = "AIzaSyA98GaV2pDkyU4DYx0IcCRNxecBtD8cXuQ"
maps = googlemaps.Client(key=my_key)  # my key값 입력
lat = []  #위도
lng = []  #경도

# 위치를 찾을 장소나 주소를 넣어준다.


places = ['광주광역시북구태봉로32유동115-1']

i=0
for place in places:   
    i = i + 1
    try:
        geo_location = maps.geocode(place)[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
        

    except:
        lat.append('')
        lng.append('')
        print("%d번 인덱스 위치를 찾는데 실패했습니다."%(i))


# 데이터프레임만들어 출력하기
df = pd.DataFrame({'위도':lat, '경도':lng}, index=places)

print(df)



'''
# output
1번 인덱스에서 강남의 위치를 찾고있습니다
2번 인덱스에서 황상동의 위치를 찾고있습니다
3번 인덱스에서 해운대해수욕장의 위치를 찾고있습니다
                위도          경도
강남       37.517236  127.047325
황상동      36.114955  128.440733
해운대해수욕장  35.158698  129.160384

'''
# Out:
#                             위도          경도
# 광주광역시북구태봉로32유동115-1  35.160472  126.903589
# '\n# output\n1번 인덱스에서 강남의 위치를 찾고있습니다\n2번 인덱스에서 황상동의 위치를 찾고있습니다\n3번 인덱스에서 해운대해수욕장의 위치를 찾고있습니다\n                위도          경도\n강남       37.517236  127.047325\n황상동      36.114955  128.440733\n해운대해수욕장  35.158698  129.160384\n\n'

# %%
df = pd.read_excel('./public_mental_final.xlsx')

df
# Out:
#       Unnamed: 0                       address         corp_name   longitude  \
# 0              0           광주광역시북구태봉로32유동115-1       (재)천주의성요한병원  126.903589
# 1              1                    관평로170번길22  (학)일송학원한림대학교성심병원  126.961754
# 2              2                 부산광역시남구수영로165              BH병원  129.084666
# 3              3         서울특별시광진구능동로3243층(중곡동)       Dr.고신경정신과의원  127.085367
# 4              4      강원도강릉시경강로21096층(임당동문선빌딩)   Dr.신형직의비타민정신과의원  128.914587
# ...          ...                           ...               ...         ...
# 1855        1855  광주광역시남구서문대로701번길2넥스타워5층(진월동)       희망정신건강의학과의원  126.898170
# 1856        1856         경기도오산시경기동로8번길28라동102호               희망집  127.074454
# 1857        1857             대전광역시대덕구송촌남로55-12              힐링타운  127.443819
# 1858        1858     경기도안산시상록구석호공원로2길7401호(사동)             힐링하우스  126.849497
# 1859        1859          대전광역시중구대흥로1053층(대흥동)    李편한마음정신건강의학과의원  127.422036
#
#        latitude
# 0     35.160472
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# address       0
# corp_name     0
# longitude     6
# latitude      6
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# address       0
# corp_name     0
# longitude     6
# latitude      6
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#       Unnamed: 0                       address         corp_name   longitude  \
# 0              0           광주광역시북구태봉로32유동115-1       (재)천주의성요한병원  126.903589
# 1              1                    관평로170번길22  (학)일송학원한림대학교성심병원  126.961754
# 2              2                 부산광역시남구수영로165              BH병원  129.084666
# 3              3         서울특별시광진구능동로3243층(중곡동)       Dr.고신경정신과의원  127.085367
# 4              4      강원도강릉시경강로21096층(임당동문선빌딩)   Dr.신형직의비타민정신과의원  128.914587
# ...          ...                           ...               ...         ...
# 1855        1855  광주광역시남구서문대로701번길2넥스타워5층(진월동)       희망정신건강의학과의원  126.898170
# 1856        1856         경기도오산시경기동로8번길28라동102호               희망집  127.074454
# 1857        1857             대전광역시대덕구송촌남로55-12              힐링타운  127.443819
# 1858        1858     경기도안산시상록구석호공원로2길7401호(사동)             힐링하우스  126.849497
# 1859        1859          대전광역시중구대흥로1053층(대흥동)    李편한마음정신건강의학과의원  127.422036
#
#        latitude
# 0     35.160472
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
# C:\Users\by_wh\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                            address         corp_name   longitude   latitude
# 0              광주광역시북구태봉로32유동115-1       (재)천주의성요한병원  126.903589  35.160472
# 1                       관평로170번길22  (학)일송학원한림대학교성심병원  126.961754  37.391431
# 2                    부산광역시남구수영로165              BH병원  129.084666  35.135073
# 3            서울특별시광진구능동로3243층(중곡동)       Dr.고신경정신과의원  127.085367  37.562620
# 4         강원도강릉시경강로21096층(임당동문선빌딩)   Dr.신형직의비타민정신과의원  128.914587  37.764222
# ...                            ...               ...         ...        ...
# 1855  광주광역시남구서문대로701번길2넥스타워5층(진월동)       희망정신건강의학과의원  126.898170  35.122123
# ...

# %%
df.index = range(len(df))

# %%
df
# Out:
#                            address         corp_name   longitude   latitude
# 0              광주광역시북구태봉로32유동115-1       (재)천주의성요한병원  126.903589  35.160472
# 1                       관평로170번길22  (학)일송학원한림대학교성심병원  126.961754  37.391431
# 2                    부산광역시남구수영로165              BH병원  129.084666  35.135073
# 3            서울특별시광진구능동로3243층(중곡동)       Dr.고신경정신과의원  127.085367  37.562620
# 4         강원도강릉시경강로21096층(임당동문선빌딩)   Dr.신형직의비타민정신과의원  128.914587  37.764222
# ...                            ...               ...         ...        ...
# 1849  광주광역시남구서문대로701번길2넥스타워5층(진월동)       희망정신건강의학과의원  126.898170  35.122123
# 1850         경기도오산시경기동로8번길28라동102호               희망집  127.074454  37.156244
# 1851             대전광역시대덕구송촌남로55-12              힐링타운  127.443819  36.356192
# 1852     경기도안산시상록구석호공원로2길7401호(사동)             힐링하우스  126.849497  37.300884
# 1853          대전광역시중구대흥로1053층(대흥동)    李편한마음정신건강의학과의원  127.422036  36.322969
#
# [1854 rows x 4 columns]

# %%
df.to_excel('./ffffffff.xlsx')
