# %%
import json
import pandas as pd
import numpy as np

# %%
with open('./hospital_psy_hira.json', 'r', encoding='utf-8') as f:
    data_hira = json.load(f)
    
df_hira = pd.DataFrame(data_hira)

# %%
with open('./mental_care_final.json', 'r', encoding='utf-8') as d:
    data_care = json.load(d)
    
df_care = pd.DataFrame(data_care)

# %%
df_care.rename(columns ={'위도':'longitude'}, inplace=True)
df_care.rename(columns ={'경도':'latitude'}, inplace=True)
df_care
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
df_hira
# Out:
#      공공/민간 기관구분                 기관명  \
# 0       민간   병원        가톨릭대학교인천성모병원
# 1       민간   병원              강릉아산병원
# 2       민간   병원              강북삼성병원
# 3       민간   병원             건국대학교병원
# 4       민간   병원             경북대학교병원
# ...    ...  ...                 ...
# 3336    민간   병원              실버한방병원
# 3337    민간   병원  의료법인 영명의료재단 혜민한방병원
# 3338    민간   병원              한도한방병원
# 3339    민간   병원              혜민한방병원
# 3340    민간   병원             힘찬큐한방병원
#
#                                                주소    longitude    latitude  \
# 0                        인천광역시 부평구 동수로 56-  (부평동)  126.7248987  37.4848309
# 1                           강원도 강릉시 사천면 방동길 38 ()  128.8578411  37.8184325
# 2                          서울특별시 종로구 새문안로 29 (평동)  126.9677500  37.5684083
# 3                       서울특별시 광진구 능동로 120-1 (화양동)  127.0718276  37.5403764
# 4               대구광역시 중구 동덕로 130 (삼덕동2가, 경북대학교병원)  128.6041250  35.8667740
# ...

# %%
df = pd.concat([df_hira, df_care])
df
# Out:
#      공공/민간 기관구분           기관명                                 주소    longitude  \
# 0       민간   병원  가톨릭대학교인천성모병원           인천광역시 부평구 동수로 56-  (부평동)  126.7248987
# 1       민간   병원        강릉아산병원              강원도 강릉시 사천면 방동길 38 ()  128.8578411
# 2       민간   병원        강북삼성병원             서울특별시 종로구 새문안로 29 (평동)  126.9677500
# 3       민간   병원       건국대학교병원          서울특별시 광진구 능동로 120-1 (화양동)  127.0718276
# 4       민간   병원       경북대학교병원  대구광역시 중구 동덕로 130 (삼덕동2가, 경북대학교병원)  128.6041250
# ...    ...  ...           ...                                ...          ...
# 997     민간   시설          희망의집             경상북도 경산시 자인면 설총로 841-9   128.826344
# 998     민간   시설          희망일터             인천광역시 강화군 화도면 마니산로 359   126.454878
# 999     민간   시설           희망집        경기도 오산시 경기동로 8번길 28 라동 102호   127.074516
# 1000    민간   시설          힐링타운                대전광역시 대덕구 송촌남로55-12   127.443816
# 1001    민간   시설         힐링하우스    경기도 안산시 상록구 석호공원로 2길7, 401호(사동)     126.8491
#
# ...

# %%
df.drop_duplicates(subset='기관명', keep='first', inplace=True, ignore_index=False)

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...
